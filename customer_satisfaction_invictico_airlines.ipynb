# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_df= pd.read_csv("C://Users/LAKSHAY WADHWANI/Desktop//DS & ML/REGRESSION(LOGIST+LINEAR)/Invistico_Airline.csv/Invistico_Airline.csv")

# %%
air_df
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
air_df.isna().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
air_df['Arrival Delay in Minutes'].fillna(air_df['Arrival Delay in Minutes'].mean(),inplace=True,axis = 0)

# %%
air_df.isna().sum()
# Out:
# satisfaction                         0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
air_df.shape
# Out:
# (129880, 22)

# %%
air_df.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %%
air_df["satisfaction"] = np.where(air_df['satisfaction']=='satisfied',1,0)

# %%
air_df["Customer Type"]= np.where(air_df["Customer Type"]=='Loyal Customer',1,0)

# %%
air_df["Type of Travel"]= np.where(air_df["Type of Travel"]=='Personal Travel',1,0)

# %%
air_df
# Out:
#         satisfaction  Customer Type  Age  Type of Travel     Class  \
# 0                  1              1   65               1       Eco
# 1                  1              1   47               1  Business
# 2                  1              1   15               1       Eco
# 3                  1              1   60               1       Eco
# 4                  1              1   70               1       Eco
# ...              ...            ...  ...             ...       ...
# 129875             1              0   29               1       Eco
# 129876             0              0   63               1  Business
# 129877             0              0   69               1       Eco
# 129878             0              0   66               1       Eco
# 129879             0              0   38               1       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                   265             0                                  0
# ...

# %%
dataset = pd.get_dummies(air_df, columns=['Class'])

# %%
dataset
# Out:
#         satisfaction  Customer Type  Age  Type of Travel  Flight Distance  \
# 0                  1              1   65               1              265
# 1                  1              1   47               1             2464
# 2                  1              1   15               1             2138
# 3                  1              1   60               1              623
# 4                  1              1   70               1              354
# ...              ...            ...  ...             ...              ...
# 129875             1              0   29               1             1731
# 129876             0              0   63               1             2087
# 129877             0              0   69               1             2320
# 129878             0              0   66               1             2450
# 129879             0              0   38               1             4307
#
#         Seat comfort  Departure/Arrival time convenient  Food and drink  \
# ...

# %%
print(pd.get_dummies(air_df['Class']))
# Out:
#         Business    Eco  Eco Plus
# 0          False   True     False
# 1           True  False     False
# 2          False   True     False
# 3          False   True     False
# 4          False   True     False
# ...          ...    ...       ...
# 129875     False   True     False
# 129876      True  False     False
# 129877     False   True     False
# 129878     False   True     False
# 129879     False   True     False
#
# [129880 rows x 3 columns]

# %%
print(dataset.columns)
# Out:
# Index(['satisfaction', 'Customer Type', 'Age', 'Type of Travel',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Gate location', 'Inflight wifi service',
#        'Inflight entertainment', 'Online support', 'Ease of Online booking',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'Class_Business', 'Class_Eco', 'Class_Eco Plus'],
#       dtype='object')

# %%
dataset['Class_Eco'] = dataset['Class_Eco'].astype(int)
dataset['Class_Eco Plus'] = dataset['Class_Eco Plus'].astype(int)
dataset['Class_Business'] = dataset['Class_Business'].astype(int)

# %%
dataset
# Out:
#         satisfaction  Customer Type  Age  Type of Travel  Flight Distance  \
# 0                  1              1   65               1              265
# 1                  1              1   47               1             2464
# 2                  1              1   15               1             2138
# 3                  1              1   60               1              623
# 4                  1              1   70               1              354
# ...              ...            ...  ...             ...              ...
# 129875             1              0   29               1             1731
# 129876             0              0   63               1             2087
# 129877             0              0   69               1             2320
# 129878             0              0   66               1             2450
# 129879             0              0   38               1             4307
#
#         Seat comfort  Departure/Arrival time convenient  Food and drink  \
# ...

# %%
label = dataset['satisfaction']
dataset.drop('satisfaction',axis=1,inplace=True)

# %%
label
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 129875    1
# 129876    0
# 129877    0
# 129878    0
# 129879    0
# Name: satisfaction, Length: 129880, dtype: int32

# %%
dataset = dataset.values # pandas to numpy
label = label.values

# %%
u = np.mean(dataset,axis=0) #axis=0 operation around row # axis = 1 toh operation around the column hota.
std = np.std(dataset,axis=0)
dataset = (dataset-u)/std

# %%
split = 0.8
x_train = dataset[:int(dataset.shape[0]*split),:] # rows from starting to 80% of total rows index and all the columns
x_test=dataset[int(dataset.shape[0]*split):,:] # rows from that 0.8 index to total no. of rows and all columns.

# %%
y_train = label[:int(dataset.shape[0]* split)]  # no columns selected as only one columns is there. strting to 80%
y_test = label[int(dataset.shape[0]*split):] # 80% sai leke end tak.

# %%
print(x_test.shape,y_test.shape,x_train.shape, y_train.shape)
# Out:
# (25976, 23) (25976,) (103904, 23) (103904,)

# %%
ones = np.ones((x_train.shape[0],1))
x_train = np.hstack((ones,x_train))
print(x_train.shape)
# Out:
# (103904, 24)

# %%
print(x_train[:10,0:4])
# Out:
# [[ 1.          0.47342178  1.69135082  1.49395144]
#  [ 1.          0.47342178  0.50081965  1.49395144]
#  [ 1.          0.47342178 -1.61568021  1.49395144]
#  [ 1.          0.47342178  1.36064772  1.49395144]
#  [ 1.          0.47342178  2.02205392  1.49395144]
#  [ 1.          0.47342178 -0.6235709   1.49395144]
#  [ 1.          0.47342178  1.75749144  1.49395144]
#  [ 1.          0.47342178 -1.94638331  1.49395144]
#  [ 1.          0.47342178  1.09608524  1.49395144]
#  [ 1.          0.47342178 -1.15269586  1.49395144]]

# %%
ones = np.ones((x_test.shape[0],1))
x_test = np.hstack((ones,x_test))
print(x_test.shape)
# Out:
# (25976, 24)

# %%
x_train[0]
# Out:
# array([ 1.        ,  0.47342178,  1.69135082,  1.49395144, -1.6711027 ,
#        -2.03779055, -1.9582301 , -1.97544301, -0.75838329, -0.94716271,
#         0.45802246, -1.16318119, -0.36161261, -0.36596177, -2.6976054 ,
#        -0.60154396,  1.31621673, -0.61276078, -1.04148541, -0.38648106,
#        -0.39292384, -0.95806953,  1.10790047, -0.27949898])

# %%
def hypothesis(X,theta):
    return 1/(1+ np.exp(-1 * np.dot(X, theta)))

# %%
def loss_func(X,Y,weights):
    h_x = hypothesis(X,weights)
    loss=np.mean(Y*np.log(h_x) + (1-Y)*np.log((1-h_x)))

    return -1*loss

# %%
def gradient(x,y,weight):
    y_pred = hypothesis(x, weight)
    grad = np.dot(x.T, (y - y_pred))
    
    return grad/x.shape[0]

# %%
def gradient_descent(x , y ,learning_rate = 0.03):
    
    weight = np.zeros((x.shape[1], ))
    
    cost = []
    
    epoch = 5000
    
    for i in range(epoch):
        grad = gradient(x,y,weight)
        
        loss = loss_func(x,y,weight)
        cost.append(loss)
        
        weight= weight + learning_rate * grad
        
        
    return cost, weight

# %%
cost, theta = gradient_descent(x_train, y_train)

# %%
cost[0], cost[-10:]
# Out:
# (0.6931471805599453,
#  [0.45910471348568727,
#   0.45910469732460507,
#   0.45910468117016356,
#   0.45910466502235847,
#   0.4591046488811854,
#   0.45910463274664043,
#   0.45910461661871893,
#   0.4591046004974167,
#   0.45910458438272933,
#   0.4591045682746528])

# %%
plt.plot(cost)

# %%
def predict(X, theta):
    h_x = hypothesis(X, theta)
    
    if (h_x >= 0.5):
        return 1
    else:
        return 0

# %%
corr = 0
for i in range(x_test.shape[0]):
    pred = predict(x_test[i], theta)
    if pred == y_test[i]:
        corr+=1
print(corr/x_test.shape[0])
# Out:
# 0.9432168155220203
